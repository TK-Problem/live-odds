# %%
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))

from IPython.display import Image, display

from scrapers.betsson.page import open_page

# %%
session = await open_page(headless=False)
# display(Image(filename=str(session.screenshot)))

# %%
html = await session.get_html(sport="basketball")
print(f"{len(html):,} chars")

# %%
df = await session.get_odds(sport="basketball")
print(df.shape)
df

# %%
df = await session.get_odds(sport="football")
print(df.shape)
df

# %%
# Run this when you're done inspecting to close the browser
await session.close()
